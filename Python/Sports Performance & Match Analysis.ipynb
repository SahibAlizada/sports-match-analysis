# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Sahib Alizada\Desktop\SHB\Real Projects\4-Sports Performance & Match Analysis\Data\E0.csv")

# %%
df.head()
# Out:
#   Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  05/08/2022  20:00  Crystal Palace        Arsenal     0     2   A     0
# 1  E0  06/08/2022  12:30          Fulham      Liverpool     2     2   D     1
# 2  E0  06/08/2022  15:00     Bournemouth    Aston Villa     2     0   H     1
# 3  E0  06/08/2022  15:00           Leeds         Wolves     2     1   H     1
# 4  E0  06/08/2022  15:00       Newcastle  Nott'm Forest     2     0   H     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     1  ...     1.76  0.50      2.09      1.84   2.04   1.88     2.09
# 1     0  ...     2.73  1.75      1.90      2.03   1.91   2.02     2.01
# 2     0  ...     1.76  0.50      1.93      2.00   1.93   2.00     1.94
# 3     1  ...     1.87 -0.25      2.08      1.85   2.10   1.84     2.14
# 4     0  ...     1.89 -1.00      1.97      1.96   1.99   1.93     2.19
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.88     2.03     1.85
# ...

# %%
df.tail()
# Out:
#     Div        Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 375  E0  28/05/2023  16:30      Everton  Bournemouth     1     0   H     0
# 376  E0  28/05/2023  16:30        Leeds    Tottenham     1     4   A     0
# 377  E0  28/05/2023  16:30    Leicester     West Ham     2     1   H     1
# 378  E0  28/05/2023  16:30   Man United       Fulham     2     1   H     1
# 379  E0  28/05/2023  16:30  Southampton    Liverpool     4     4   D     2
#
#      HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 375     0  ...     2.14 -1.00      2.02      1.77   2.10   1.81     2.17
# 376     1  ...     2.50  0.25      1.84      2.06   1.83   2.10     1.90
# 377     0  ...     2.51 -0.25      1.75      2.05   1.85   2.06     1.90
# 378     1  ...     2.95 -1.25      1.98      1.92   1.98   1.93     2.07
# 379     2  ...     3.22  1.25      1.82      2.08   1.85   2.07     1.96
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 375     1.92     2.03     1.83
# ...

# %%
df.shape
# Out:
# (380, 106)

# %%
result_counts = df["FTR"].value_counts(normalize=True)*100
result_counts
# Out:
# FTR
# H    48.421053
# A    28.684211
# D    22.894737
# Name: proportion, dtype: float64

# %%
df[["FTHG","FTAG"]].mean()
# Out:
# FTHG    1.634211
# FTAG    1.218421
# dtype: float64

# %%
home_goals=df.groupby("HomeTeam")["FTHG"].sum()
away_goals=df.groupby("AwayTeam")["FTAG"].sum()

total_goals=home_goals.add(away_goals,fill_value=0)
total_goals.sort_values(ascending=False).head(10)
# Out:
# HomeTeam
# Man City       94
# Arsenal        88
# Liverpool      75
# Brighton       72
# Tottenham      70
# Newcastle      68
# Brentford      58
# Man United     58
# Fulham         55
# Aston Villa    51
# dtype: int64

# %%
home_wins=df[df["FTR"]=="H"]["HomeTeam"].value_counts()
away_wins=df[df["FTR"]=="A"]["AwayTeam"].value_counts()

total_wins=home_wins.add(away_wins,fill_value=0)
total_wins.sort_values(ascending=False).head(10)
# Out:
# Man City       28
# Arsenal        26
# Man United     23
# Liverpool      19
# Newcastle      19
# Brighton       18
# Tottenham      18
# Aston Villa    18
# Brentford      15
# Fulham         15
# Name: count, dtype: int64

# %%
team_stats = pd.DataFrame({
    "Total_Goals": total_goals,
    "Total_Wins": total_wins
}).fillna(0)

team_stats.reset_index(inplace=True)
team_stats.columns = ["Team", "Total_Goals", "Total_Wins"]

team_stats.to_csv("team_performance_stats.csv", index=False)
